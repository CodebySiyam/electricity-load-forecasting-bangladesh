# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("electricity_demand_weather_merged.csv")

# %%
df.head()
# Out:
#               datetime  generation_mw  demand_mw  load_shedding   gas  \
# 0  2020-01-01 00:00:00         5913.0       5913              0  5493
# 1  2020-01-01 01:00:00         5570.0       5570              0  5117
# 2  2020-01-01 02:00:00         5351.0       5351              0  4900
# 3  2020-01-01 03:00:00         5223.0       5223              0  4773
# 4  2020-01-01 04:00:00         5142.0       5142              0  4697
#
#    liquid_fuel  coal  hydro  solar  wind  india_bheramara_hvdc  india_tripura  \
# 0            0   160     47    0.0   NaN                   129             76
# 1            0   160     47    0.0   NaN                   129             74
# 2            0   159     47    0.0   NaN                   129             72
# 3            0   160     46    0.0   NaN                   129             70
# 4            0   159     46    0.0   NaN                   129             68
#
#    india_adani  nepal remarks  temperature  humidity  rain  windspeed
# ...

# %%
df=df.rename(columns={
    'generation_mw': 'total_generation_mw',
    'demand_mw': 'demand_mw',
    'load_shedding': 'load_shedding_mw',
    'gas': 'gen_gas_mw',
    'liquid_fuel': 'gen_liquid_fuel_mw',
    'coal': 'gen_coal_mw',
    'hydro': 'gen_hydro_mw',
    'solar': 'gen_solar_mw',
    'wind': 'gen_wind_mw',
    'india_bheramara_hvdc': 'import_india_bheramara_mw',
    'india_tripura': 'import_india_tripura_mw',
    'india_adani': 'import_india_adani_mw',
    'nepal': 'import_nepal_mw',
    'temperature': 'temp_c',
    'humidity': 'humidity_pct',
    'rain': 'rain_mm',
    'windspeed': 'wind_speed_ms'
})

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
df = df.set_index("datetime")

# %%
df.isna().sum()
# Out:
# total_generation_mw              0
# demand_mw                        0
# load_shedding_mw                 0
# gen_gas_mw                       0
# gen_liquid_fuel_mw               0
# gen_coal_mw                      0
# gen_hydro_mw                     0
# gen_solar_mw                     0
# gen_wind_mw                  31188
# import_india_bheramara_mw        0
# import_india_tripura_mw          0
# import_india_adani_mw        42526
# import_nepal_mw              44513
# remarks                      46058
# temp_c                        1991
# humidity_pct                  1991
# rain_mm                       1991
# wind_speed_ms                 1991
# dtype: int64

# %%
df.sample(5)
# Out:
#                      total_generation_mw  demand_mw  load_shedding_mw  \
# datetime
# 2022-12-10 10:00:00               7467.0       7467                 0
# 2024-08-29 07:00:00              11668.0      11970               288
# 2021-04-30 01:00:00              11908.0      11908                 0
# 2022-04-19 05:00:00              10870.0      10870                 0
# 2021-08-09 22:00:00              12399.0      12399                 0
#
#                      gen_gas_mw  gen_liquid_fuel_mw  gen_coal_mw  \
# datetime
# 2022-12-10 10:00:00        4551                 919          883
# 2024-08-29 07:00:00        4891                1129         3490
# 2021-04-30 01:00:00        6514                3546          754
# 2022-04-19 05:00:00        6291                3137          325
# 2021-08-09 22:00:00        6619                4117          716
#
#                      gen_hydro_mw  gen_solar_mw  gen_wind_mw  \
# datetime
# ...

# %%
df = df.drop(columns=['gen_wind_mw'])

# %%
df.isna().sum()
# Out:
# total_generation_mw              0
# demand_mw                        0
# load_shedding_mw                 0
# gen_gas_mw                       0
# gen_liquid_fuel_mw               0
# gen_coal_mw                      0
# gen_hydro_mw                     0
# gen_solar_mw                     0
# import_india_bheramara_mw        0
# import_india_tripura_mw          0
# import_india_adani_mw        42526
# import_nepal_mw              44513
# remarks                      46058
# temp_c                        1991
# humidity_pct                  1991
# rain_mm                       1991
# wind_speed_ms                 1991
# dtype: int64
